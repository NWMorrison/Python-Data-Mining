# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # New

# %%
df_iris = pd.read_csv('/content/iris.csv', header=None)

df_iris
# Out:
#        0    1    2    3  4
# 0    5.7  2.9  4.2  1.3  2
# 1    4.8  3.0  1.4  0.3  1
# 2    5.0  3.2  1.2  0.2  1
# 3    6.5  3.0  5.8  2.2  3
# 4    7.2  3.6  6.1  2.5  3
# ..   ...  ...  ...  ... ..
# 145  7.7  2.8  6.7  2.0  3
# 146  5.8  4.0  1.2  0.2  1
# 147  5.2  2.7  3.9  1.4  2
# 148  6.0  3.0  4.8  1.8  3
# 149  5.0  3.6  1.4  0.2  1
#
# [150 rows x 5 columns]

# %%
df_iris.columns = ['x1', 'x2', 'x3', 'x4', 'labels']

# This turns our 'labels' into an actual array out to console
df_iris['labels'].to_numpy()
# Out:
# array([2, 1, 1, 3, 3, 2, 2, 3, 2, 3, 1, 3, 2, 3, 1, 2, 2, 2, 2, 3, 2, 3,
#        1, 2, 2, 3, 1, 3, 3, 1, 3, 3, 2, 1, 2, 1, 1, 1, 3, 3, 3, 1, 1, 1,
#        2, 2, 2, 1, 3, 1, 2, 3, 1, 2, 3, 3, 1, 2, 2, 3, 2, 3, 3, 3, 3, 1,
#        2, 3, 3, 3, 1, 1, 1, 3, 1, 3, 2, 2, 1, 2, 3, 2, 1, 3, 3, 2, 3, 3,
#        2, 3, 2, 1, 1, 2, 2, 2, 2, 3, 1, 2, 2, 1, 1, 3, 2, 1, 2, 1, 1, 3,
#        2, 1, 2, 1, 1, 3, 3, 1, 2, 1, 2, 2, 3, 3, 1, 1, 2, 3, 1, 3, 1, 3,
#        2, 3, 1, 3, 2, 2, 1, 2, 1, 1, 2, 1, 1, 3, 1, 2, 3, 1])

# %%
# Provides to rows & columns
print(df_iris.shape)

# Just provides the length of the Dataframe
print(len(df_iris))

# it is better to use loc or iloc, see documentation
df_iris.iloc[5:10]
# Out:
# (150, 5)
# 150
#     x1   x2   x3   x4  labels
# 5  5.5  2.4  3.7  1.0       2
# 6  6.1  2.8  4.0  1.3       2
# 7  6.7  2.5  5.8  1.8       3
# 8  6.0  2.7  5.1  1.6       2
# 9  7.1  3.0  5.9  2.1       3

# %%
plt.plot(df_iris)
plt.title('Iris Dataset')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %%
counts, bins = np.histogram(df_iris)
plt.stairs(counts, bins)

# %%
# Applying a scatter plot to our Dataframe

plt.scatter(df_iris['x3'], df_iris['x4'])
plt.title('Iris Dataset')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.show()

# %%
# see the matplot lib documentation for colors, markers, plot()
condition1 = labels==1
condition2 = labels==2
condition3 = labels==3
plt.plot(df_iris[condition1,2], df_iris[condition1,3], 'bx')
plt.plot(df_iris[condition2,2], df_iris[condition2,3], 'g+')
plt.plot(df_iris[condition3,2], df_iris[condition3,3], 'r.')
plt.title('Iris Dataset')
plt.xlabel('x2')
plt.ylabel('x3')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 145    False
# 146     True
# 147    False
# 148    False
# 149     True
# Name: labels, Length: 150, dtype: bool, 2)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-27-1e4db9deabdc> in <cell line: 6>()
#       4 condition2 = labels==2
# ...

# %%
import matplotlib.pyplot as plt

# see the matplot lib documentation for colors, markers, plot()
plt.plot(df_iris[:,2], df_iris[:,3], '.')
plt.title('Iris Dataset')
plt.xlabel('x2')
plt.ylabel('x3')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 2)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# <ipython-input-30-0a739c64b587> in <cell line: 4>()
#       2
#       3 # see the matplot lib documentation for colors, markers, plot()
# ----> 4 plt.plot(df_iris[:,2], df_iris[:,3], '.')
#       5 plt.title('Iris Dataset')
#       6 plt.xlabel('x2')
#
# ...

# %%
#using pandas dataframes and map()
colors = {1:'red', 2:'green', 3:'blue'}
plt.scatter(df_iris['x1'], df_iris['x3'], 20, df_iris['labels'].map(colors))
plt.title('Iris Dataset')
plt.xlabel('x1')
plt.ylabel('x3')
plt.show()
